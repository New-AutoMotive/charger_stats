# %% [markdown]
# <a href="https://colab.research.google.com/github/New-AutoMotive/charger_stats/blob/main/02)_Charging_device_grant_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Run this block if running this notebook in Colab

# !pip install odfpy
# Out:
# Requirement already satisfied: odfpy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from odfpy) (0.7.1)

# %% [markdown]
# This script will download and clean up the DfT's charging device grant scheme statistics, which show how many grants have been awarded under each of the UK's charging device grant schemes.
#
# There are 12 tables in the excel file, which will be imported and cleaned here, making it easy to do analysis of the data.
#
# ![image.png](data:image/png;base64,...)

# %%
# Paste the latest link to the data here:

url = 'https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/1032677/electric-vehicle-charging-device-grant-scheme-statistics-october-2021.ods'

# %%
# Import ORCs statistics

df_evg09 = pd.read_excel(url, engine='odf', sheet_name='EVG_09')

# %%
# Clean up EVG_09

df_evg09.columns = df_evg09.iloc[6]
df_evg09 = df_evg09.iloc[7:-5]

# %%
df_evg09.to_csv('evg09.csv')
